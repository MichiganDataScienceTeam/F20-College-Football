# %% [markdown]
# ## Importing data

# %%
import pandas as pd

player_recruit_df = pd.read_csv("../data/player_recruit_df.csv")

# %%
player_recruit_df.head()
# Out:
#   recruitType  year  ranking            name                     school  \
# 0  HighSchool  2000      1.0   D.J. Williams                De La Salle
# 1  HighSchool  2000      2.0    Brock Berlin  Evangel Christian Academy
# 2  HighSchool  2000      3.0  Charles Rogers                    Saginaw
# 3  HighSchool  2000      4.0  Travis Johnson                 Notre Dame
# 4  HighSchool  2000      5.0  Marcus Houston           Thomas Jefferson
#
#       committedTo position  height  weight  stars  rating          city  \
# 0           Miami      ILB    74.0   235.0      5  0.9998       Concord
# 1         Florida      PRO    74.0   190.0      5  0.9998    Shreveport
# 2  Michigan State       WR    76.0   195.0      5  0.9988       Saginaw
# 3   Florida State      SDE    76.0   265.0      5  0.9982  Sherman Oaks
# 4        Colorado       RB    72.0   208.0      5  0.9980        Denver
#
#   stateProvince country
# 0            CA     NaN
# 1            LA     NaN
# ...

# %% [markdown]
# ## Outliers

# %%
player_recruit_df.describe()
# Out:
#                year       ranking        height        weight         stars  \
# count  61883.000000  52971.000000  61711.000000  61707.000000  61883.000000
# mean    2012.364252   1204.053331     73.944412    220.942373      2.551315
# std        5.392012    958.189671     21.315765     45.447649      0.759072
# min     2000.000000      1.000000      6.300000    -21.000000      1.000000
# 25%     2008.000000    356.000000     72.000000    185.000000      2.000000
# 50%     2013.000000   1019.000000     74.000000    210.000000      2.000000
# 75%     2017.000000   1854.000000     76.000000    250.000000      3.000000
# max     2020.000000   4297.000000   5330.000000   2224.000000      5.000000
#
#              rating
# count  61883.000000
# mean       0.801951
# std        0.066378
# min        0.496300
# 25%        0.764800
# 50%        0.795300
# 75%        0.842100
# max        1.000000

# %%
player_recruit_df[player_recruit_df.weight>1000]
# Out:
#       recruitType  year  ranking           name               school  \
# 14768  HighSchool  2008    438.0   Kenny Demens  Detroit Country Day
# 35522  HighSchool  2014   3507.0  Marques Moore          Springfield
#
#       committedTo position  height  weight  stars  rating            city  \
# 14768    Michigan      ILB    73.0  2224.0      3  0.8028        Franklin
# 35522  Kent State      ILB    74.0  2000.0      1  0.6997  New Middletown
#
#       stateProvince country
# 14768            MI     NaN
# 35522            OH     NaN

# %%
player_recruit_df[player_recruit_df.height>100]
# Out:
#       recruitType  year  ranking               name  \
# 16801  PrepSchool  2008     12.0        Leon Mackey
# 20755  HighSchool  2010   1330.0     JaQwaylin Arps
# 20869  HighSchool  2010   1444.0  Pierce Richardson
#
#                           school    committedTo position  height  weight  \
# 16801  Hargrave Military Academy  Virginia Tech      SDE  5330.0     2.0
# 20755                    Denison         Kansas      WDE   104.0   235.0
# 20869                     Crespi     Iowa State       TE   114.0   218.0
#
#        stars  rating     city stateProvince country
# 16801      3  0.8748  Chatham            VA     NaN
# 20755      2  0.7743  Denison            TX     NaN
# 20869      2  0.7692   Encino            CA     NaN

# %%
import seaborn as sns

sns.pairplot(player_recruit_df)
